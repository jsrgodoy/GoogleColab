# %% [markdown]
# <a href="https://colab.research.google.com/github/jsrgodoy/GoogleColab/blob/main/regarPlanta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![583eda62-c0eb-4fa0-b498-1eb3d8fce7bf.png](data:image/png;base64,...)

# %%
for i in range(6):
  if(i > 2):
   planta = str(i)
   print("Regar batata " + planta)
# Out:
# Regar batata 3
# Regar batata 4
# Regar batata 5

# %%
i = 0
while (i < 6):
  if(i > 2):
   print("Regar batata "+ str(i))
  i = i+1
# Out:
# Regar batata 3
# Regar batata 4
# Regar batata 5

# %% [markdown]
# ![aa25f890-be9e-4ada-948a-3c99ab39ec1f.png](data:image/png;base64,...)

# %%
for i in range(6):
  if(i < 2) or (i > 3):
   planta = str(i)
   print("Regar tomate " + planta)
# Out:
# Regar tomate 0
# Regar tomate 1
# Regar tomate 4
# Regar tomate 5

# %%
i = 0
while (i < 6):
  if(i < 2) or (i > 3):
   print("Regar tomate "+ str(i))
  i = i+1
# Out:
# Regar tomate 0
# Regar tomate 1
# Regar tomate 4
# Regar tomate 5

# %% [markdown]
# ![b413268b-ec81-474b-a7a2-dcb49779a8c2.png](data:image/png;base64,...)

# %%
for i in range(5, -1, -1):
  planta = str(i)
  print("Regar planta " + planta)
# Out:
# Regar planta 5
# Regar planta 4
# Regar planta 3
# Regar planta 2
# Regar planta 1
# Regar planta 0

# %%
i = 5
while (i >= 0):
  print("Regar tomate "+ str(i))
  i = i-1
# Out:
# Regar tomate 5
# Regar tomate 4
# Regar tomate 3
# Regar tomate 2
# Regar tomate 1
# Regar tomate 0
